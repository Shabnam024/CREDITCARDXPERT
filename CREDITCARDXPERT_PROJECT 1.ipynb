# %%
import pandas as pd

# %%
import numpy as np

# %%
spend=pd.read_excel("Credit Banking_Project1new.xlsx","Spend",header=None,names=["SI No.","Customer","Month","Type","Amount"],skiprows=1)

# %%
spend
# Out:
#       SI No. Customer      Month        Type         Amount
# 0          1       A1 2004-01-12   JEWELLERY  473775.834869
# 1          2       A1 2004-01-03       PETRO  335578.666019
# 2          3       A1 2004-01-15     CLOTHES  371040.941912
# 3          4       A1 2004-01-25        FOOD  141177.813256
# 4          5       A1 2005-01-17      CAMERA  398403.771812
# ...      ...      ...        ...         ...            ...
# 1495    1496      A67 2006-02-04  BUS TICKET  195841.312215
# 1496    1497      A68 2006-03-25  BUS TICKET  284262.517709
# 1497    1498      A69 2006-03-31  BUS TICKET  206552.273598
# 1498    1499      A70 2006-03-23  BUS TICKET   41024.781283
# 1499    1500      A71 2006-03-24  BUS TICKET  101397.548588
#
# [1500 rows x 5 columns]

# %%
repayment=pd.read_excel("Credit Banking_Project1new.xlsx","Repayment",header=None,names=["SI No.","Customer","Month","Amount"],skiprows=1)

# %%
repayment
# Out:
#       SI No. Customer      Month         Amount
# 0          1       A1 2004-01-12  331844.007374
# 1          2       A1 2004-01-03  441139.807335
# 2          3       A1 2004-01-15   32480.004009
# 3          4       A1 2004-01-25   90636.966534
# 4          5       A1 2005-01-17    1581.969829
# ...      ...      ...        ...            ...
# 1495    1496      A67 2005-05-09  200288.874065
# 1496    1497      A68 2006-05-10  231194.702295
# 1497    1498      A69 2006-07-11  391195.615836
# 1498    1499      A70 2005-08-12  357629.618186
# 1499    1500      A71 2004-09-13  179771.745248
#
# [1500 rows x 4 columns]

# %%
customer_acqusition=pd.read_excel("Credit Banking_Project1new.xlsx","Customer Acqusition",header=None,names=["SI No.","Customer","Age","City","Credit card Product","Limit","Company","Segment"],skiprows=1)

# %%
customer_acqusition
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 0        1       A1   0.928521   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  11.559307      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# 2       C3   Salaried_Pvt
# ...

# %%
customer_acqusition
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 0        1       A1   0.928521   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  11.559307      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# 2       C3   Salaried_Pvt
# ...

# %%
new1=customer_acqusition[customer_acqusition["Age"]>18]

# %%
new1
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# 5        6       A6  35.578586       DELHI              Silver  100000
# 6        7       A7  52.102217      COCHIN              Silver  100001
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 1       C2   Salaried_MNC
# 3       C4           Govt
# 4       C5  Normal Salary
# ...

# %%
mean_age=new1["Age"].mean()

# %%
mean_age
# Out:
# 49.29242405876662

# %%
customer_acqusition.loc[customer_acqusition["Age"]<18,"Age"]=mean_age

# %%
customer_acqusition_new=customer_acqusition

# %%
customer_acqusition_new
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 0        1       A1  49.292424   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  49.292424      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# 2       C3   Salaried_Pvt
# ...

# %%
repayment
# Out:
#       SI No. Customer      Month         Amount
# 0          1       A1 2004-01-12  331844.007374
# 1          2       A1 2004-01-03  441139.807335
# 2          3       A1 2004-01-15   32480.004009
# 3          4       A1 2004-01-25   90636.966534
# 4          5       A1 2005-01-17    1581.969829
# ...      ...      ...        ...            ...
# 1495    1496      A67 2005-05-09  200288.874065
# 1496    1497      A68 2006-05-10  231194.702295
# 1497    1498      A69 2006-07-11  391195.615836
# 1498    1499      A70 2005-08-12  357629.618186
# 1499    1500      A71 2004-09-13  179771.745248
#
# [1500 rows x 4 columns]

# %%
spend
# Out:
#       SI No. Customer      Month        Type         Amount
# 0          1       A1 2004-01-12   JEWELLERY  473775.834869
# 1          2       A1 2004-01-03       PETRO  335578.666019
# 2          3       A1 2004-01-15     CLOTHES  371040.941912
# 3          4       A1 2004-01-25        FOOD  141177.813256
# 4          5       A1 2005-01-17      CAMERA  398403.771812
# ...      ...      ...        ...         ...            ...
# 1495    1496      A67 2006-02-04  BUS TICKET  195841.312215
# 1496    1497      A68 2006-03-25  BUS TICKET  284262.517709
# 1497    1498      A69 2006-03-31  BUS TICKET  206552.273598
# 1498    1499      A70 2006-03-23  BUS TICKET   41024.781283
# 1499    1500      A71 2006-03-24  BUS TICKET  101397.548588
#
# [1500 rows x 5 columns]

# %%
new_amount=repayment["Amount"]-spend["Amount"]

# %%
new_amount
# Out:
# 0      -141931.827495
# 1       105561.141316
# 2      -338560.937903
# 3       -50540.846722
# 4      -396821.801983
#             ...
# 1495      4447.561849
# 1496    -53067.815415
# 1497    184643.342238
# 1498    316604.836903
# 1499     78374.196661
# Name: Amount, Length: 1500, dtype: float64

# %%
repayment["Difference"]=new_amount

# %%
surplus=repayment["Difference"]*0.02

# %%
surplus
# Out:
# 0      -2838.636550
# 1       2111.222826
# 2      -6771.218758
# 3      -1010.816934
# 4      -7936.436040
#            ...
# 1495      88.951237
# 1496   -1061.356308
# 1497    3692.866845
# 1498    6332.096738
# 1499    1567.483933
# Name: Difference, Length: 1500, dtype: float64

# %%
repayment["Surplus amount"]=surplus

# %%
repayment
# Out:
#       SI No. Customer      Month         Amount     Difference  Surplus amount
# 0          1       A1 2004-01-12  331844.007374 -141931.827495    -2838.636550
# 1          2       A1 2004-01-03  441139.807335  105561.141316     2111.222826
# 2          3       A1 2004-01-15   32480.004009 -338560.937903    -6771.218758
# 3          4       A1 2004-01-25   90636.966534  -50540.846722    -1010.816934
# 4          5       A1 2005-01-17    1581.969829 -396821.801983    -7936.436040
# ...      ...      ...        ...            ...            ...             ...
# 1495    1496      A67 2005-05-09  200288.874065    4447.561849       88.951237
# 1496    1497      A68 2006-05-10  231194.702295  -53067.815415    -1061.356308
# 1497    1498      A69 2006-07-11  391195.615836  184643.342238     3692.866845
# 1498    1499      A70 2005-08-12  357629.618186  316604.836903     6332.096738
# 1499    1500      A71 2004-09-13  179771.745248   78374.196661     1567.483933
#
# [1500 rows x 6 columns]

# %%
Surplus_Table = repayment.drop(["Difference"],axis=1)

# %%
Surplus_Table=Surplus_Table[Surplus_Table["Surplus amount"]>0]

# %%
Surplus_Table
# Out:
#       SI No. Customer      Month         Amount  Surplus amount
# 1          2       A1 2004-01-03  441139.807335     2111.222826
# 6          7       A1 2005-02-01  280990.709927     1232.974963
# 7          8       A8 2004-02-05  117697.053061     1147.908167
# 9         10      A10 2005-02-16  407418.805366     6726.031867
# 11        12      A12 2005-02-03  227656.566154     2663.728573
# ...      ...      ...        ...            ...             ...
# 1494    1495      A66 2006-05-08  419497.942321     8373.440204
# 1495    1496      A67 2005-05-09  200288.874065       88.951237
# 1497    1498      A69 2006-07-11  391195.615836     3692.866845
# 1498    1499      A70 2005-08-12  357629.618186     6332.096738
# 1499    1500      A71 2004-09-13  179771.745248     1567.483933
#
# [712 rows x 5 columns]

# %%
spend
# Out:
#       SI No. Customer      Month        Type         Amount
# 0          1       A1 2004-01-12   JEWELLERY  473775.834869
# 1          2       A1 2004-01-03       PETRO  335578.666019
# 2          3       A1 2004-01-15     CLOTHES  371040.941912
# 3          4       A1 2004-01-25        FOOD  141177.813256
# 4          5       A1 2005-01-17      CAMERA  398403.771812
# ...      ...      ...        ...         ...            ...
# 1495    1496      A67 2006-02-04  BUS TICKET  195841.312215
# 1496    1497      A68 2006-03-25  BUS TICKET  284262.517709
# 1497    1498      A69 2006-03-31  BUS TICKET  206552.273598
# 1498    1499      A70 2006-03-23  BUS TICKET   41024.781283
# 1499    1500      A71 2006-03-24  BUS TICKET  101397.548588
#
# [1500 rows x 5 columns]

# %%
spend["Month"]=pd.to_datetime(spend["Month"]).dt.to_period('M')

# %%
Monthly_spend=spend.groupby(["Customer","Month"])["Amount"].sum()

# %%
Monthly_spend.head(10)
# Out:
# Customer  Month
# A1        2004-01    1.511173e+06
#           2004-02    4.138111e+04
#           2004-05    1.311966e+05
#           2005-01    3.984038e+05
#           2005-02    1.404193e+06
#           2005-08    1.293883e+05
#           2005-11    4.573169e+05
#           2006-04    5.645069e+05
#           2006-10    2.207350e+05
# A10       2004-01    7.474281e+05
# Name: Amount, dtype: float64

# %%
repayment_original=repayment.drop(["Difference","Surplus amount"],axis=1)

# %%
repayment_original
# Out:
#       SI No. Customer      Month         Amount
# 0          1       A1 2004-01-12  331844.007374
# 1          2       A1 2004-01-03  441139.807335
# 2          3       A1 2004-01-15   32480.004009
# 3          4       A1 2004-01-25   90636.966534
# 4          5       A1 2005-01-17    1581.969829
# ...      ...      ...        ...            ...
# 1495    1496      A67 2005-05-09  200288.874065
# 1496    1497      A68 2006-05-10  231194.702295
# 1497    1498      A69 2006-07-11  391195.615836
# 1498    1499      A70 2005-08-12  357629.618186
# 1499    1500      A71 2004-09-13  179771.745248
#
# [1500 rows x 4 columns]

# %%
repayment_original["Month"]=pd.to_datetime(repayment_original["Month"]).dt.to_period('M')

# %%
Monthly_repayment=repayment_original.groupby(["Customer","Month"])["Amount"].sum()

# %%
Monthly_repayment
# Out:
# Customer  Month
# A1        2004-01    1.362775e+06
#           2004-02    1.911800e+05
#           2005-01    1.581970e+03
#           2005-02    1.199808e+06
#           2005-07    3.005817e+05
#                          ...
# A95       2004-01    7.510949e+04
# A96       2004-01    1.101390e+05
# A97       2004-01    1.746064e+05
# A98       2004-01    9.780260e+04
# A99       2004-01    3.585899e+05
# Name: Amount, Length: 798, dtype: float64

# %%
repayment_original
# Out:
#       SI No. Customer    Month         Amount
# 0          1       A1  2004-01  331844.007374
# 1          2       A1  2004-01  441139.807335
# 2          3       A1  2004-01   32480.004009
# 3          4       A1  2004-01   90636.966534
# 4          5       A1  2005-01    1581.969829
# ...      ...      ...      ...            ...
# 1495    1496      A67  2005-05  200288.874065
# 1496    1497      A68  2006-05  231194.702295
# 1497    1498      A69  2006-07  391195.615836
# 1498    1499      A70  2005-08  357629.618186
# 1499    1500      A71  2004-09  179771.745248
#
# [1500 rows x 4 columns]

# %%
Highest_paying=repayment.groupby(["Customer"])["Amount"].sum()

# %%
Highest_paying
# Out:
# Customer
# A1      3.831938e+06
# A10     5.230312e+06
# A100    1.511414e+05
# A11     4.735300e+06
# A12     7.572754e+06
#             ...
# A95     7.510949e+04
# A96     1.101390e+05
# A97     1.746064e+05
# A98     9.780260e+04
# A99     3.585899e+05
# Name: Amount, Length: 100, dtype: float64

# %%
Highest_paying.nlargest(10)
# Out:
# Customer
# A22    9.767171e+06
# A60    9.262032e+06
# A61    8.807888e+06
# A40    8.805085e+06
# A47    8.529826e+06
# A43    8.458621e+06
# A48    8.432804e+06
# A41    8.374046e+06
# A49    8.259841e+06
# A45    8.115210e+06
# Name: Amount, dtype: float64

# %%
customer_acqusition_new
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 0        1       A1  49.292424   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  49.292424      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment
# 0       C1  Self Employed
# 1       C2   Salaried_MNC
# 2       C3   Salaried_Pvt
# ...

# %%
customer_acqusition_new["Segment"]
# Out:
# 0     Self Employed
# 1      Salaried_MNC
# 2      Salaried_Pvt
# 3              Govt
# 4     Normal Salary
#           ...
# 95     Salaried_Pvt
# 96             Govt
# 97    Normal Salary
# 98    Self Employed
# 99     Salaried_MNC
# Name: Segment, Length: 100, dtype: object

# %%
spend["Amount"]
# Out:
# 0       473775.834869
# 1       335578.666019
# 2       371040.941912
# 3       141177.813256
# 4       398403.771812
#             ...
# 1495    195841.312215
# 1496    284262.517709
# 1497    206552.273598
# 1498     41024.781283
# 1499    101397.548588
# Name: Amount, Length: 1500, dtype: float64

# %%
customer_acqusition_new["Spending_Amount"]=spend["Amount"]

# %%
customer_acqusition_new
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 0        1       A1  49.292424   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  49.292424      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment  Spending_Amount
# 0       C1  Self Employed    473775.834869
# ...

# %%
Highest_segment=customer_acqusition_new.groupby(["Segment"])["Spending_Amount"].sum()

# %%
Highest_segment.nlargest(5)
# Out:
# Segment
# Govt             7.635182e+06
# Self Employed    7.131656e+06
# Normal Salary    6.156305e+06
# Salaried_Pvt     3.892088e+06
# Salaried_MNC     3.209916e+06
# Name: Spending_Amount, dtype: float64

# %%
Highest_Age_Group=customer_acqusition_new.groupby(["Age"])["Spending_Amount"].sum()

# %%
Highest_Age_Group.head(5)
# Out:
# Age
# 18.158058    199770.925237
# 19.098781     69630.290140
# 19.181051     56941.681091
# 20.611833    347833.879524
# 21.588666    164330.042270
# Name: Spending_Amount, dtype: float64

# %%
Highest_Age_Group.nlargest(5)
# Out:
# Age
# 49.292424    6.840231e+06
# 58.078266    4.946778e+05
# 39.369536    4.743938e+05
# 70.737891    4.734157e+05
# 67.883059    4.720445e+05
# Name: Spending_Amount, dtype: float64

# %%
customer_acqusition_new
# Out:
#     SI No. Customer        Age        City Credit card Product   Limit  \
# 0        1       A1  49.292424   BANGALORE                Gold  500000
# 1        2       A2  35.534551    CALCUTTA              Silver  100000
# 2        3       A3  49.292424      COCHIN            Platimum   10000
# 3        4       A4  45.820278      BOMBAY            Platimum   10001
# 4        5       A5  69.663948   BANGALORE            Platimum   10002
# ..     ...      ...        ...         ...                 ...     ...
# 95      96      A96  29.631637     CHENNAI              Silver  100000
# 96      97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 97      98      A98  40.538985    CALCUTTA            Platimum   10001
# 98      99      A99  21.588666    CALCUTTA            Platimum   10002
# 99     100     A100  23.607638      COCHIN              Silver  100000
#
#    Company        Segment  Spending_Amount
# 0       C1  Self Employed    473775.834869
# ...

# %%
Surplus_Table
# Out:
#       SI No. Customer      Month         Amount  Surplus amount
# 1          2       A1 2004-01-03  441139.807335     2111.222826
# 6          7       A1 2005-02-01  280990.709927     1232.974963
# 7          8       A8 2004-02-05  117697.053061     1147.908167
# 9         10      A10 2005-02-16  407418.805366     6726.031867
# 11        12      A12 2005-02-03  227656.566154     2663.728573
# ...      ...      ...        ...            ...             ...
# 1494    1495      A66 2006-05-08  419497.942321     8373.440204
# 1495    1496      A67 2005-05-09  200288.874065       88.951237
# 1497    1498      A69 2006-07-11  391195.615836     3692.866845
# 1498    1499      A70 2005-08-12  357629.618186     6332.096738
# 1499    1500      A71 2004-09-13  179771.745248     1567.483933
#
# [712 rows x 5 columns]

# %%
Merged_Tables=pd.merge(customer_acqusition_new,Surplus_Table,on="Customer",how="left")

# %%
Merged_Tables
# Out:
#      SI No._x Customer        Age        City Credit card Product   Limit  \
# 0           1       A1  49.292424   BANGALORE                Gold  500000
# 1           1       A1  49.292424   BANGALORE                Gold  500000
# 2           1       A1  49.292424   BANGALORE                Gold  500000
# 3           1       A1  49.292424   BANGALORE                Gold  500000
# 4           1       A1  49.292424   BANGALORE                Gold  500000
# ..        ...      ...        ...         ...                 ...     ...
# 724        96      A96  29.631637     CHENNAI              Silver  100000
# 725        97      A97  20.611833  TRIVANDRUM            Platimum   10000
# 726        98      A98  40.538985    CALCUTTA            Platimum   10001
# 727        99      A99  21.588666    CALCUTTA            Platimum   10002
# 728       100     A100  23.607638      COCHIN              Silver  100000
#
#     Company        Segment  Spending_Amount  SI No._y      Month  \
# ...

# %%
Profit=Merged_Tables.groupby(["Segment"])["Surplus amount"].sum()

# %%
Profit.head(5)
# Out:
# Segment
# Govt             449109.616593
# Normal Salary    698705.805643
# Salaried_MNC     404130.254767
# Salaried_Pvt     420326.367540
# Self Employed    457127.537213
# Name: Surplus amount, dtype: float64

# %%
Profit.nlargest(5)
# Out:
# Segment
# Normal Salary    698705.805643
# Self Employed    457127.537213
# Govt             449109.616593
# Salaried_Pvt     420326.367540
# Salaried_MNC     404130.254767
# Name: Surplus amount, dtype: float64

# %%
Surplus_Table
# Out:
#       SI No. Customer      Month         Amount  Surplus amount
# 1          2       A1 2004-01-03  441139.807335     2111.222826
# 6          7       A1 2005-02-01  280990.709927     1232.974963
# 7          8       A8 2004-02-05  117697.053061     1147.908167
# 9         10      A10 2005-02-16  407418.805366     6726.031867
# 11        12      A12 2005-02-03  227656.566154     2663.728573
# ...      ...      ...        ...            ...             ...
# 1494    1495      A66 2006-05-08  419497.942321     8373.440204
# 1495    1496      A67 2005-05-09  200288.874065       88.951237
# 1497    1498      A69 2006-07-11  391195.615836     3692.866845
# 1498    1499      A70 2005-08-12  357629.618186     6332.096738
# 1499    1500      A71 2004-09-13  179771.745248     1567.483933
#
# [712 rows x 5 columns]

# %%
Surplus_Table["Month"]=pd.to_datetime(Surplus_Table["Month"]).dt.to_period("M")

# %%
Monthly_profit=Surplus_Table.groupby(["Month"])["Surplus amount"].sum()

# %%
Monthly_profit
# Out:
# Month
# 2004-01    388144.979129
# 2004-02     28733.633141
# 2004-03     35826.331119
# 2004-04     48189.891476
# 2004-05     42894.703686
# 2004-09     31937.521177
# 2004-11     16202.310407
# 2005-01     83460.978097
# 2005-02    281015.051910
# 2005-04     38325.927756
# 2005-05    242394.830790
# 2005-06     50276.119595
# 2005-07     22285.448824
# 2005-08     71150.996757
# 2005-09     22377.030004
# 2005-10     16418.930800
# 2005-11     91586.927304
# 2005-12     22377.073755
# 2006-01      7859.187190
# 2006-02     53719.631949
# 2006-03    339373.682854
# 2006-04    156066.926461
# 2006-05    165501.603115
# 2006-06     12246.527061
# 2006-07     61442.821919
# 2006-08     23211.998857
# 2006-09     15961.418665
# 2006-10      6801.226930
# 2006-11     34771.861620
# 2006-12     18844.009405
# Freq: M, Name: Surplus amount, dtype: float64

# %%
spend
# Out:
#       SI No. Customer    Month        Type         Amount
# 0          1       A1  2004-01   JEWELLERY  473775.834869
# 1          2       A1  2004-01       PETRO  335578.666019
# 2          3       A1  2004-01     CLOTHES  371040.941912
# 3          4       A1  2004-01        FOOD  141177.813256
# 4          5       A1  2005-01      CAMERA  398403.771812
# ...      ...      ...      ...         ...            ...
# 1495    1496      A67  2006-02  BUS TICKET  195841.312215
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709
# 1497    1498      A69  2006-03  BUS TICKET  206552.273598
# 1498    1499      A70  2006-03  BUS TICKET   41024.781283
# 1499    1500      A71  2006-03  BUS TICKET  101397.548588
#
# [1500 rows x 5 columns]

# %%
spend["Repay amount"]=repayment["Amount"]

# %%
spend
# Out:
#       SI No. Customer    Month        Type         Amount   Repay amount
# 0          1       A1  2004-01   JEWELLERY  473775.834869  331844.007374
# 1          2       A1  2004-01       PETRO  335578.666019  441139.807335
# 2          3       A1  2004-01     CLOTHES  371040.941912   32480.004009
# 3          4       A1  2004-01        FOOD  141177.813256   90636.966534
# 4          5       A1  2005-01      CAMERA  398403.771812    1581.969829
# ...      ...      ...      ...         ...            ...            ...
# 1495    1496      A67  2006-02  BUS TICKET  195841.312215  200288.874065
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709  231194.702295
# 1497    1498      A69  2006-03  BUS TICKET  206552.273598  391195.615836
# 1498    1499      A70  2006-03  BUS TICKET   41024.781283  357629.618186
# 1499    1500      A71  2006-03  BUS TICKET  101397.548588  179771.745248
#
# [1500 rows x 6 columns]

# %%
Differences=spend["Amount"]-spend["Repay amount"]

# %%
spend["Due amount"]=Differences

# %%
spend
# Out:
#       SI No. Customer    Month        Type         Amount   Repay amount  \
# 0          1       A1  2004-01   JEWELLERY  473775.834869  331844.007374
# 1          2       A1  2004-01       PETRO  335578.666019  441139.807335
# 2          3       A1  2004-01     CLOTHES  371040.941912   32480.004009
# 3          4       A1  2004-01        FOOD  141177.813256   90636.966534
# 4          5       A1  2005-01      CAMERA  398403.771812    1581.969829
# ...      ...      ...      ...         ...            ...            ...
# 1495    1496      A67  2006-02  BUS TICKET  195841.312215  200288.874065
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709  231194.702295
# 1497    1498      A69  2006-03  BUS TICKET  206552.273598  391195.615836
# 1498    1499      A70  2006-03  BUS TICKET   41024.781283  357629.618186
# 1499    1500      A71  2006-03  BUS TICKET  101397.548588  179771.745248
#
#          Due amount
# 0     141931.827495
# 1    -105561.141316
# 2     338560.937903
# ...

# %%
Duesss=spend["Due amount"]*0.029

# %%
Duesss
# Out:
# 0        4116.022997
# 1       -3061.273098
# 2        9818.267199
# 3        1465.684555
# 4       11507.832258
#             ...
# 1495     -128.979294
# 1496     1538.966647
# 1497    -5354.656925
# 1498    -9181.540270
# 1499    -2272.851703
# Name: Due amount, Length: 1500, dtype: float64

# %%
spend["Intrest_amount"]=Duesss

# %%
spend
# Out:
#       SI No. Customer    Month        Type         Amount   Repay amount  \
# 0          1       A1  2004-01   JEWELLERY  473775.834869  331844.007374
# 1          2       A1  2004-01       PETRO  335578.666019  441139.807335
# 2          3       A1  2004-01     CLOTHES  371040.941912   32480.004009
# 3          4       A1  2004-01        FOOD  141177.813256   90636.966534
# 4          5       A1  2005-01      CAMERA  398403.771812    1581.969829
# ...      ...      ...      ...         ...            ...            ...
# 1495    1496      A67  2006-02  BUS TICKET  195841.312215  200288.874065
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709  231194.702295
# 1497    1498      A69  2006-03  BUS TICKET  206552.273598  391195.615836
# 1498    1499      A70  2006-03  BUS TICKET   41024.781283  357629.618186
# 1499    1500      A71  2006-03  BUS TICKET  101397.548588  179771.745248
#
#          Due amount  Intrest_amount
# 0     141931.827495     4116.022997
# ...

# %%
Dues_Table=spend[spend["Intrest_amount"]>0]

# %%
Dues_Table
# Out:
#       SI No. Customer    Month        Type         Amount   Repay amount  \
# 0          1       A1  2004-01   JEWELLERY  473775.834869  331844.007374
# 2          3       A1  2004-01     CLOTHES  371040.941912   32480.004009
# 3          4       A1  2004-01        FOOD  141177.813256   90636.966534
# 4          5       A1  2005-01      CAMERA  398403.771812    1581.969829
# 5          6       A1  2005-02     SANDALS  429084.568141  357678.507744
# ...      ...      ...      ...         ...            ...            ...
# 1489    1490      A61  2005-02      CAMERA  441486.726003   47988.236722
# 1490    1491      A62  2004-02    SHOPPING  242398.024134  227455.913837
# 1491    1492      A63  2005-02  AIR TICKET  475612.350971  308213.767472
# 1493    1494      A65  2005-02  BUS TICKET  446973.201616  236963.950008
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709  231194.702295
#
#          Due amount  Intrest_amount
# 0     141931.827495     4116.022997
# ...

# %%
Intrest=Dues_Table.groupby(["Customer","Month"])["Intrest_amount"].sum()

# %%
Intrest.head(10)
# Out:
# Customer  Month
# A1        2004-01    15399.974751
#           2005-01    11507.832258
#           2005-02    18625.330967
#           2005-08     3232.250492
#           2005-11     5186.084011
#           2006-04     1888.985729
# A10       2004-01    12544.614930
#           2004-03     4878.646162
#           2004-05     5492.529133
#           2005-02      840.509855
# Name: Intrest_amount, dtype: float64

# %%
Intrest.nlargest(10)
# Out:
# Customer  Month
# A14       2005-02    33526.337602
# A42       2004-01    31042.814635
# A13       2005-02    31021.316586
# A21       2006-03    30327.257316
# A60       2004-01    30213.448838
# A16       2006-03    30133.815221
# A37       2004-01    29844.825391
# A40       2006-04    27942.566703
# A14       2006-03    26995.531216
# A36       2004-01    24795.542724
# Name: Intrest_amount, dtype: float64

# %%
spend
# Out:
#       SI No. Customer    Month        Type         Amount   Repay amount  \
# 0          1       A1  2004-01   JEWELLERY  473775.834869  331844.007374
# 1          2       A1  2004-01       PETRO  335578.666019  441139.807335
# 2          3       A1  2004-01     CLOTHES  371040.941912   32480.004009
# 3          4       A1  2004-01        FOOD  141177.813256   90636.966534
# 4          5       A1  2005-01      CAMERA  398403.771812    1581.969829
# ...      ...      ...      ...         ...            ...            ...
# 1495    1496      A67  2006-02  BUS TICKET  195841.312215  200288.874065
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709  231194.702295
# 1497    1498      A69  2006-03  BUS TICKET  206552.273598  391195.615836
# 1498    1499      A70  2006-03  BUS TICKET   41024.781283  357629.618186
# 1499    1500      A71  2006-03  BUS TICKET  101397.548588  179771.745248
#
#          Due amount  Intrest_amount
# 0     141931.827495     4116.022997
# ...

# %%
spend['Type'].unique()
# Out:
# array(['JEWELLERY', 'PETRO', 'CLOTHES', 'FOOD', 'CAMERA', 'SANDALS',
#        'CAR', 'BIKE', 'AUTO', 'SHOPPING', 'AIR TICKET', 'BUS TICKET',
#        'TRAIN TICKET', 'RENTAL', 'MOVIE TICKET'], dtype=object)

# %%
grouped_category = {
    'JEWELLERY' : 'FASHION AND ACCESORIES',
    'PETRO' : 'AutoMobile',
    'CLOTHES' : 'FASHION AND ACCESORIES',
    'FOOD' : 'FOOD',
    'CAMERA' : 'OTHERS',
    'SANDALS' : 'FASHION AND ACCESORIES',
    'CAR' : 'AutoMobile',
    'BIKE' : 'AutoMobile',
    'AUTO' : 'AutoMobile',
    'SHOPPING' : 'FASHION AND ACCESORIES',
    'AIR TICKET' : 'TRAVELING EXPENSES',
    'BUS TICKET' : 'TRAVELING EXPENSES',
    'TRAIN TICKET': 'TRAVELING EXPENSES',
    'RENTAL' : 'OTHERS',
    'MOVIE TICKET' : 'OTHERS'
}

# %%
spend["Category"]=spend["Type"].replace(grouped_category)

# %%
spend
# Out:
#       SI No. Customer    Month        Type         Amount   Repay amount  \
# 0          1       A1  2004-01   JEWELLERY  473775.834869  331844.007374
# 1          2       A1  2004-01       PETRO  335578.666019  441139.807335
# 2          3       A1  2004-01     CLOTHES  371040.941912   32480.004009
# 3          4       A1  2004-01        FOOD  141177.813256   90636.966534
# 4          5       A1  2005-01      CAMERA  398403.771812    1581.969829
# ...      ...      ...      ...         ...            ...            ...
# 1495    1496      A67  2006-02  BUS TICKET  195841.312215  200288.874065
# 1496    1497      A68  2006-03  BUS TICKET  284262.517709  231194.702295
# 1497    1498      A69  2006-03  BUS TICKET  206552.273598  391195.615836
# 1498    1499      A70  2006-03  BUS TICKET   41024.781283  357629.618186
# 1499    1500      A71  2006-03  BUS TICKET  101397.548588  179771.745248
#
#          Due amount  Intrest_amount                Category
# ...

# %%
category_spend=spend.groupby(["Category"])["Amount"].sum()

# %%
category_spend.head(5)
# Out:
# Category
# AutoMobile                8.169858e+07
# FASHION AND ACCESORIES    8.378275e+07
# FOOD                      3.829646e+07
# OTHERS                    8.342026e+07
# TRAVELING EXPENSES        9.415399e+07
# Name: Amount, dtype: float64

# %%
category_spend.nlargest(5)
# Out:
# Category
# TRAVELING EXPENSES        9.415399e+07
# FASHION AND ACCESORIES    8.378275e+07
# OTHERS                    8.342026e+07
# AutoMobile                8.169858e+07
# FOOD                      3.829646e+07
# Name: Amount, dtype: float64
